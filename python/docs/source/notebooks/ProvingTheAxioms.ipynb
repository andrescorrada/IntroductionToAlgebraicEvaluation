# %%
import itertools, random
import sympy
from IPython.display import display,Math,Latex, HTML
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

import ntqr
import ntqr.raxioms

# We want Latex in output cells to be left aligned
display(HTML("""
<style>
div.output_area .MathJax_Display,
div.output_area mjx-container[jax="CHTML"][display="true"] {
    text-align: left !important;
    margin-left: 0 !important;
}
</style>
"""))
sympy.init_session()
# Out:
# <style>
# div.output_area .MathJax_Display,
# div.output_area mjx-container[jax="CHTML"][display="true"] {
#     text-align: left !important;
#     margin-left: 0 !important;
# }
# </style>
# IPython console for SymPy 1.14.0 (Python 3.13.9-64-bit) (ground types: gmpy)
#
# These commands were executed:
# >>> from sympy import *
# >>> x, y, z, t = symbols('x y z t')
# >>> k, m, n = symbols('k m n', integer=True)
# >>> f, g, h = symbols('f g h', cls=Function)
# >>> init_printing()
#
# Documentation can be found at https://docs.sympy.org/1.14.0/

# %%
labels = ('a','b')
classifiers = (1,2,3)
mIdeal = ntqr.raxioms.MAxiomsIdeal(labels,classifiers,2)

# %%
Matrix([mIdeal.m_two_ideal_agreement((1,2))[label] for label in labels])
# Out:
# ⎡Qₐ - R_{a_{1},a_{2},a} - R_{b_{1},b_{2},b} + R_{b_{1},b_{2}} + R_{b_{1},b} -  ↪
# ⎢                                                                              ↪
# ⎣Q_b - R_{a_{1},a_{2},a} + R_{a_{1},a_{2}} + R_{a_{1},a} - R_{a_{1}} + R_{a_{2 ↪
#
# ↪ R_{b_{1}} + R_{b_{2},b} - R_{b_{2}} ⎤
# ↪                                     ⎥
# ↪ },a} - R_{a_{2}} - R_{b_{1},b_{2},b}⎦

# %%
labels = ('a','b','c')
classifiers = (1,2,3)
mIdeal = ntqr.raxioms.MAxiomsIdeal(labels,classifiers,2)
Matrix([mIdeal.m_two_ideal_agreement((1,2))[label] for label in labels])
# Out:
# ⎡Qₐ - R_{a_{1},a_{2},a} - R_{b_{1},b_{2},b} - R_{b_{1},b_{2},c} + R_{b_{1},b_{ ↪
# ⎢                                                                              ↪
# ⎢Q_b - R_{a_{1},a_{2},a} - R_{a_{1},a_{2},c} + R_{a_{1},a_{2}} + R_{a_{1},a} + ↪
# ⎢                                                                              ↪
# ⎣Q_c - R_{a_{1},a_{2},a} - R_{a_{1},a_{2},b} + R_{a_{1},a_{2}} + R_{a_{1},a} + ↪
#
# ↪ 2}} + R_{b_{1},b} + R_{b_{1},c_{2},a} + R_{b_{1},c} - R_{b_{1}} + R_{b_{2},b ↪
# ↪                                                                              ↪
# ↪  R_{a_{1},c_{2},b} + R_{a_{1},c} - R_{a_{1}} + R_{a_{2},a} + R_{a_{2},c} - R ↪
# ↪                                                                              ↪
# ↪  R_{a_{1},b_{2},c} + R_{a_{1},b} - R_{a_{1}} + R_{a_{2},a} + R_{a_{2},b} - R ↪
#
# ↪ } + R_{b_{2},c} - R_{b_{2}} + R_{c_{1},b_{2},a} + R_{c_{1},b} - R_{c_{1},c_{ ↪
# ↪                                                                              ↪
# ...

# %%
mIdeal.all_agree_subs_dict
# Out:
# {R_{a_{1},a_{2},a}: Qₐ - R_{a_{1},b_{2},a} - R_{a_{1},c_{2},a} - R_{b_{1},a_{2 ↪
#
# ↪ },a} - R_{b_{1},b_{2},a} - R_{b_{1},c_{2},a} - R_{c_{1},a_{2},a} - R_{c_{1}, ↪
#
# ↪ b_{2},a} - R_{c_{1},c_{2},a}, R_{a_{1},a_{3},a}: Qₐ - R_{a_{1},b_{3},a} - R_ ↪
#
# ↪ {a_{1},c_{3},a} - R_{b_{1},a_{3},a} - R_{b_{1},b_{3},a} - R_{b_{1},c_{3},a}  ↪
#
# ↪ - R_{c_{1},a_{3},a} - R_{c_{1},b_{3},a} - R_{c_{1},c_{3},a}, R_{a_{1},a}: Qₐ ↪
#
# ↪  - R_{b_{1},a} - R_{c_{1},a}, R_{a_{2},a_{3},a}: Qₐ - R_{a_{2},b_{3},a} - R_ ↪
#
# ↪ {a_{2},c_{3},a} - R_{b_{2},a_{3},a} - R_{b_{2},b_{3},a} - R_{b_{2},c_{3},a}  ↪
#
# ↪ - R_{c_{2},a_{3},a} - R_{c_{2},b_{3},a} - R_{c_{2},c_{3},a}, R_{a_{2},a}: Qₐ ↪
#
# ↪  - R_{b_{2},a} - R_{c_{2},a}, R_{a_{3},a}: Qₐ - R_{b_{3},a} - R_{c_{3},a}, R ↪
#
# ↪ _{b_{1},b_{2},b}: Q_b - R_{a_{1},a_{2},b} - R_{a_{1},b_{2},b} - R_{a_{1},c_{ ↪
#
# ↪ 2},b} - R_{b_{1},a_{2},b} - R_{b_{1},c_{2},b} - R_{c_{1},a_{2},b} - R_{c_{1} ↪
#
# ...
