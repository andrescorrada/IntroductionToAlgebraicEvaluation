# %%
import itertools, random
import sympy
from IPython.display import display,Math,Latex, HTML
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

import ntqr
import ntqr.raxioms
sympy.init_session()
sympy.init_printing(latex_mode='equation',fontsize='14pt',print_builtin=True)
# Out:
# IPython console for SymPy 1.13.3 (Python 3.11.8-64-bit) (ground types: gmpy)
#
# These commands were executed:
# >>> from sympy import *
# >>> x, y, z, t = symbols('x y z t')
# >>> k, m, n = symbols('k m n', integer=True)
# >>> f, g, h = symbols('f g h', cls=Function)
# >>> init_printing()
#
# Documentation can be found at https://docs.sympy.org/1.13.3/

# %%
labels = ('a','b')
classifiers = (1,2,3)
mIdeal = ntqr.raxioms.MAxiomsIdeal(labels,classifiers,2)

# %%
Matrix([mIdeal.m_two_ideal_agreement_representation((1,2))[label] for label in labels])
# Out:
# ⎡Qₐ - R_{a_{1},a_{2},a} - R_{b_{1},b_{2},b} + R_{b_{1},b_{2}} - R_{b_{1}} - R_ ↪
# ⎢                                                                              ↪
# ⎣Q_b - R_{a_{1},a_{2},a} + R_{a_{1},a_{2}} - R_{a_{1}} - R_{a_{2}} - R_{b_{1}, ↪
#
# ↪ {b_{2}} ⎤
# ↪         ⎥
# ↪ b_{2},b}⎦

# %%
labels = ('a','b','c')
classifiers = (1,2,3)
mIdeal = ntqr.raxioms.MAxiomsIdeal(labels,classifiers,2)
Matrix([mIdeal.m_two_ideal_agreement_representation((1,2))[label] for label in labels])
# Out:
# ⎡Qₐ - R_{a_{1},a_{2},a} + 2⋅R_{a_{1},b_{2},a} + 2⋅R_{a_{1},c_{2},a} + 2⋅R_{b_{ ↪
# ⎢                                                                              ↪
# ⎢Q_b - R_{a_{1},a_{2},a} + 2⋅R_{a_{1},a_{2},b} - R_{a_{1},a_{2},c} + R_{a_{1}, ↪
# ⎢                                                                              ↪
# ⎣Q_c - R_{a_{1},a_{2},a} - R_{a_{1},a_{2},b} + 2⋅R_{a_{1},a_{2},c} + R_{a_{1}, ↪
#
# ↪ 1},a_{2},a} + 2⋅R_{b_{1},b_{2},a} - R_{b_{1},b_{2},b} - R_{b_{1},b_{2},c} +  ↪
# ↪                                                                              ↪
# ↪ a_{2}} + 2⋅R_{a_{1},b_{2},b} + 2⋅R_{a_{1},c_{2},b} + R_{a_{1},c} - R_{a_{1}} ↪
# ↪                                                                              ↪
# ↪ a_{2}} + 2⋅R_{a_{1},b_{2},c} + R_{a_{1},b} + 2⋅R_{a_{1},c_{2},c} - R_{a_{1}} ↪
#
# ↪ R_{b_{1},b_{2}} + 2⋅R_{b_{1},c_{2},a} + R_{b_{1},c} - R_{b_{1}} + R_{b_{2},c ↪
# ↪                                                                              ↪
# ...
